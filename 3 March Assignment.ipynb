# %%
#Que1
'''Seaborn is a popular Python library used for data visualization. Here are five types of plots that can be created using Seaborn along with their uses:

scatterplot
histplot
relpolt
pairplot
catplot
Use:
1. scatterplot: This plot is used to show the relationship between two continuous variables. It can help in identifying any patterns or trends in the data

2. histplot: This plot is used to create a histogram of a variable or a dataset. A histogram is a type of plot that displays the distribution of continuous numerical data.

3. relpolt: This plot is used to create a relational plot, it is a flexible function that can craete different types of plots depending on the input data and type of plot to be created.

4. pairplot: This plot is used to create a pairwise plot for a dataset. It creates scatter plots between all pairs of variables in the dataset and histograms along the diagonal to show the distribution of each variable.

5. catplot: This is used to create several types of categorical plots such as bar plots, box plots, strip plots, violin plots, etc. It allows the user to specify the type of plot, the variables to be plotted, and the data to be used. can also be used to group data by one or more variables and to apply statistical functions to the groups.'''
# Out:
# 'Seaborn is a popular Python library used for data visualization. Here are five types of plots that can be created using Seaborn along with their uses:\n\nscatterplot\nhistplot\nrelpolt\npairplot\ncatplot\nUse:\n1. scatterplot: This plot is used to show the relationship between two continuous variables. It can help in identifying any patterns or trends in the data\n\n2. histplot: This plot is used to create a histogram of a variable or a dataset. A histogram is a type of plot that displays the distribution of continuous numerical data.\n\n3. relpolt: This plot is used to create a relational plot, it is a flexible function that can craete different types of plots depending on the input data and type of plot to be created.\n\n4. pairplot: This plot is used to create a pairwise plot for a dataset. It creates scatter plots between all pairs of variables in the dataset and histograms along the diagonal to show the distribution of each variable.\n\n5. catplot: This is used to create severa
# ...

# %%
#Que2
import seaborn as sns

fmri=sns.load_dataset('fmri')

# %%
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.lineplot(x=fmri['timepoint'],y=fmri['signal'])
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x=fmri['timepoint'],y=fmri['signal'],data=fmri,hue='event')
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x=fmri['timepoint'],y=fmri['signal'],data=fmri,style='region')
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x="timepoint", y="signal", hue="event", style="region", data=fmri)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
#Que3
titanic=sns.load_dataset('titanic')

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
# box1:
sns.boxplot(x='pclass',y='age',data=titanic)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='age'>

# %%
# box2:
sns.boxplot(x='pclass',y='fare',data=titanic)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %%
#Que4
diamonds=sns.load_dataset('diamonds')

# %%
diamonds
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.histplot(data=diamonds,x='price', hue='cut',kde=True)
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %%
#Que5
iris=sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(data=iris,hue='species')

# %%
#Que6
flights=sns.load_dataset('flights')

# %%
flights
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
flights = flights.pivot("year","month", "passengers")
# Out:
# /tmp/ipykernel_84/643697694.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = flights.pivot("year","month", "passengers")

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,20))
sns.heatmap(data=flights,annot=True,robust=True)
# Out:
# <AxesSubplot: xlabel='month', ylabel='year'>
